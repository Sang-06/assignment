# %% [markdown]
# * 1 Load and Inspect the Data*

# %%
import pandas as pd
data = {
    "Brand": ["Maruti", "Hyundai", "Maruti", "Honda", "Toyota", "Honda"],
    "Year": [2018, 2017, 2018, 2016, 2019, 2015],
    "Fuel": ["Petrol", "Diesel", "Petrol", "Petrol", "Diesel", "Petrol"],
    "KMs Driven": [30000, 40000, 30000, None, 20000, 70000],
    "Price": [400000, 500000, 400000, 450000, 800000, -200000]
        }

df = pd.DataFrame(data)
print("Initial Data:\n", df)
# Out:
# Initial Data:
#       Brand  Year    Fuel  KMs Driven   Price
# 0   Maruti  2018  Petrol     30000.0  400000
# 1  Hyundai  2017  Diesel     40000.0  500000
# 2   Maruti  2018  Petrol     30000.0  400000
# 3    Honda  2016  Petrol         NaN  450000
# 4   Toyota  2019  Diesel     20000.0  800000
# 5    Honda  2015  Petrol     70000.0 -200000

# %% [markdown]
# * 2 Clean the Data*

# %%
# 1. Fill missing KMs Driven with median
df['KMs Driven'] = df['KMs Driven'].fillna(df['KMs Driven'].median())

# 2. Remove negative/zero Price
df = df[df['Price'] > 0]

# 3. Remove duplicates
df = df.drop_duplicates()

print("Cleaned Data:\n", df)
# Out:
# Cleaned Data:
#       Brand  Year    Fuel  KMs Driven   Price
# 0   Maruti  2018  Petrol     30000.0  400000
# 1  Hyundai  2017  Diesel     40000.0  500000
# 3    Honda  2016  Petrol     30000.0  450000
# 4   Toyota  2019  Diesel     20000.0  800000

# %% [markdown]
# * 3a Map the Fuel Column*

# %%
df['Fuel'] = df['Fuel'].map({'Petrol': 0, 'Diesel': 1})
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, 0 to 4
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Year           4 non-null      int64
#  1   Fuel           0 non-null      float64
#  2   KMs Driven     4 non-null      float64
#  3   Price          4 non-null      int64
#  4   Brand_Honda    4 non-null      bool
#  5   Brand_Hyundai  4 non-null      bool
#  6   Brand_Maruti   4 non-null      bool
#  7   Brand_Toyota   4 non-null      bool
# dtypes: bool(4), float64(2), int64(2)
# memory usage: 176.0 bytes

# %% [markdown]
# * 3b One-Hot Encode the Brand

# %%
import pandas as pd
df = pd.get_dummies(df, columns=['Brand'])
df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_21789/3168187051.py in <cell line: 0>()
#       1 import pandas as pd
# ----> 2 df = pd.get_dummies(df, columns=['Brand'])
#       3 df.head()
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/reshape/encoding.py in get_dummies(data, prefix, prefix_sep, dummy_na, columns, sparse, drop_first, dtype)
#     167             raise TypeError("Input must be a list-like for parameter `columns`")
#     168         else:
# --> 169             data_to_encode = data[columns]
#     170
#     171         # validate prefixes and separator to avoid silently dropping cols
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4106             if is_iterator(key):
#    4107                 key = list(key)
# -> 4108             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4109
#    4110         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    6198             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    6199
# -> 6200         self._raise_if_missing(keyarr, indexer, axis_name)
#    6201
#    6202         keyarr = self.take(indexer)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in _raise_if_missing(self, key, indexer, axis_name)
#    6247         if nmissing:
#    6248             if nmissing == len(indexer):
# -> 6249                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6250
#    6251             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#
# KeyError: "None of [Index(['Brand'], dtype='object')] are in the [columns]"

# %% [markdown]
# * 3c Separate X and Y *
